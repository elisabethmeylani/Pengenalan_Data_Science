# %% [markdown]
# # 16 Classification Task dengan Random Forest
# Referensi: https://en.wikipedia.org/wiki/Random_foresing

# %% [markdown]
# ## General ML Model Training
#
# ![image.png](attachment:94971f6b-d904-47df-af1e-7542ef60bab7.png)
#
# ## Ensemble Learning: heterogeneous & homogeneous
# Referensi: https://en.wikipedia.org/wiki/Ensemble_learning
#
# ![image.png](attachment:5ca4b24b-6100-45f5-bab8-5c11ba2db7ec.png)
#
# ## Bagging: Bootstrap Aggregating
# Referensi: https://en.wikipedia.org/wiki/Bootstrap_aggregating
# ![image.png](attachment:22000de6-4a9e-4a1d-966a-16c669d3797a.png)
#
# ## Random Forest
# Referensi: https://en.wikipedia.org/wiki/Random_forest
# ![image.png](attachment:98f570d1-d458-4fd4-9d7d-048207c7aed1.png)
#
#
#
# ## Datas
# Referensi: https://en.wikipedia.org/wiki/Iris_flower_data_setet

# %%
from sklearn.datasets import load_iris

X, y = load_iris(return_X_y=True)

print(f'Dimensi Feature: {X.shape}')
print(f'Class: {set(y)}')
# Out:
# Dimensi Feature: (150, 4)
# Class: {0, 1, 2}

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size=0.3,
                                                    random_state=0)

# %% [markdown]
# ## Classification dengan RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100, 
                               random_state=0)

model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %% [markdown]
# ## Evaluasi Model

# %%
from sklearn.metrics import classification_report

y_pred = model.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       1.00      0.94      0.97        18
#            2       0.92      1.00      0.96        11
#
#     accuracy                           0.98        45
#    macro avg       0.97      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45

# %% [markdown]
# # 13 Classification Task dengan Naive Bayes
# Referensi: https://en.wikipedia.org/wiki/Naive_Bayes_classifier
#
# ## Bayes' Theorem
# Bayes' theorem menawarkan suatu formula untuk menghitung nilai probability dari suatu event dengan memanfaatkan pengetahuan sebelumnya dari kondisi terkait; atau sering kali dikenal dengan istilah conditional probability.
#
# ![image.png](attachment:3a962a50-eb4a-4948-ada6-9330a648b2ff.png)
#
# ## Pengenalan Naive Bayes Classification
# Studi Kasus 1
# ![image.png](attachment:925d69be-4bf8-4e1d-8190-41383e5cd6ec.png)
#
# Prior Probability:
#
# -
# Referensi: https://en.wikipedia.org/wiki/Prior_probabilit
#
# ![image.png](attachment:7ff71cbc-d60c-4a60-963d-e674835b4dbd.png)
#
# Likelihood:
# Referensi: https://en.wikipedia.org/wiki/Likelihood_function
# -
#
# As
#
#   ![image.png](attachment:0714fb8d-f088-409e-b627-33d3e61f629b.png)
#
# - Joko:
#
#   ![image.png](attachment:d35181fd-ed7d-49ad-a25f-d860f8223d96.png)e
# Evidence atau Normalizer:
#
# ![image.png](attachment:b0e4d6bc-7b5e-4e8e-80a4-46a01952c123.png)
#
# Posterior Probability:
#
# ![image.png](attachment:f089c304-edf0-426a-8d61-f15708682703.png)
#
#
# - Referensi: https://en.wikipedia.org/wiki/Posterior_probability
#
# -
# Formul
#
#  ![image.png](attachment:d9010641-c807-46f5-9791-3ce8eb486bf6.png)
#
# - Asep: ![image.png](attachment:beb6c712-10aa-465d-adfd-5b1746805fc2.png)
#
# - Joko: ![image.png](attachment:7297a2d6-1abf-45d0-82c4-f2fafe9c9283.png)
#
#
# Studi Kasus 2
#
# ![image.png](attachment:0951845e-0d39-4d61-a550-5f6ea97af2df.png)
#
# ![image.png](attachment:374391e2-bde6-4251-b77f-c246a4fc9ed2.png)
#
# Referensi: https://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+(Diagnostic))
# ##
# Load Dataset
# a:p:

# %%
from sklearn.datasets import load_breast_cancer

print(load_breast_cancer().DESCR)
# Out:
# .. _breast_cancer_dataset:
#
# Breast cancer wisconsin (diagnostic) dataset
# --------------------------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 569
#
#     :Number of Attributes: 30 numeric, predictive attributes and the class
#
#     :Attribute Information:
#         - radius (mean of distances from center to points on the perimeter)
#         - texture (standard deviation of gray-scale values)
#         - perimeter
#         - area
#         - smoothness (local variation in radius lengths)
#         - compactness (perimeter^2 / area - 1.0)
#         - concavity (severity of concave portions of the contour)
#         - concave points (number of concave portions of the contour)
#         - symmetry
#         - fractal dimension ("coastline approximation" - 1)
#
#         The mean, standard error, and "worst" or largest (mean of the three
#         worst/largest values) of these features were computed for each image,
# ...

# %%
# load_breast_cancer?
X, y = load_breast_cancer(return_X_y=True)
X.shape
# Out:
# (569, 30)

# %% [markdown]
# ## Training & Testing Set

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size=0.2,
                                                    random_state=0)

print(f'X_train shape {X_train.shape}')
print(f'X_test shape {X_test.shape}')
# Out:
# X_train shape (455, 30)
# X_test shape (114, 30)

# %% [markdown]
# ## Naive Bayes dengan Scikit Learn

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

model = GaussianNB()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.9298245614035088

# %%
model.score(X_test, y_test)
# Out:
# 0.9298245614035088
